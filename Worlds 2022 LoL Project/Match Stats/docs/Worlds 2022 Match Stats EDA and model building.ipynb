# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data_l = ['Days 1-2.csv', 'Days 3-4.csv', 'Days 5-6.csv', 'Days 7-8.csv', 'Tiebreakers.csv', 'Quarterfinals.csv', 'Semifinals and Finals.csv']
df_list = [pd.read_csv('../data/'+x) for x in data_l]

keys= [x.split('.')[0] for x in data_l]


roles=['Top', 'Jungle', 'Mid', 'Bottom', 'Support']
df = pd.concat(df_list, keys=keys, ignore_index=True)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df.corr()
sns.heatmap(df.corr(), cmap='jet').set(title='Correlation Heat Map')
plt.show()

# %%
df['Victory'].value_counts()
# Out:
# 0    80
# 1    80
# Name: Victory, dtype: int64

# %%
df[df['Victory']==1]['Side'].value_counts()
# Out:
# Blue    42
# Red     38
# Name: Side, dtype: int64

# %%
sns.barplot(x=df[df['Victory']==1]['Side'].value_counts().index, y=df[df['Victory']==1]['Side'].value_counts()).set(ylabel='Wins', title='Blue wins vs Red wins')
# Out:
# [Text(0, 0.5, 'Wins'), Text(0.5, 1.0, 'Blue wins vs Red wins')]

# %%
df
# Out:
#      Game Number  Match Length (minutes)  Side                Team  \
# 0              1                   32.40  Blue              Cloud9
# 1              1                   32.40   Red              Fnatic
# 2              2                   32.47  Blue          G2 Esports
# 3              2                   32.47   Red             DWG KIA
# 4              3                   31.85  Blue  CTBC Flying Oyster
# 5              3                   31.85   Red         100 Thieves
# 6              4                   29.77  Blue           JD Gaming
# 7              4                   29.77   Red       Evil Geniuses
# 8              5                   22.87  Blue                  T1
# 9              5                   22.87   Red       EDward Gaming
# 10             6                   30.13  Blue               Gen.G
# 11             6                   30.13   Red                 RNG
# 12             7                   36.17  Blue               Rogue
# ...

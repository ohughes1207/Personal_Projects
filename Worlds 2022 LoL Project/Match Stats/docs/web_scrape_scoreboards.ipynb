# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import numpy as np
import time

# %%
url = 'https://lol.fandom.com/wiki/2022_Season_World_Championship/Main_Event/Scoreboards'

PATH = "C:\geckodriver.exe"
service = Service(PATH)
driver = webdriver.Firefox(service=service)
driver.get(url)
driver.implicitly_wait(10)
#Click element to accept cookies popup
driver.find_element('css selector', ".NN0_TB_DIsNmMHgJWgT7U").click()

# %%
scoreboards_found = driver.find_elements('xpath', '/html/body/div[4]/div[3]/div[3]/main/div[3]/div[1]/div/div[2]/div/table/tbody')
len(scoreboards_found)
# Out:
# 12

# %%
test_s = scoreboards_found[0]

columns = ['Match Length (minutes)', 'Side', 'Team', 'Top', 'Top Champion', 'Jungle', 'Jungle Champion', 'Mid', 'Mid Champion', 'Bottom', 'Bottom Champion', 'Support', 'Support Champion', 'Total Team Kills', 'Total Team Gold (k)', 'Towers', 'Inhibitors', 'Barons', 'Dragons', 'Heralds', 'Victory']
BlueTeam= test_s.find_element('xpath', './tr[1]/th[1]/span/span[2]/a').text
RedTeam= test_s.find_element('xpath', './tr[1]/th[3]/span/span[1]/a').text
sides = test_s.find_elements('xpath', './tr[5]/td')
teamStats = [test_s.find_element('xpath', './tr[3]/th[1]'), test_s.find_element('xpath', './tr[3]/th[3]')]
gameLength = (float(test_s.find_element('xpath', './tr[3]/th[2]').text.split(':')[0]) + np.divide(float(test_s.find_element('xpath', './tr[3]/th[2]').text.split(':')[1]), 60))
objStats = test_s.find_elements('xpath', './tr[7]/td')
matchData = []
teams = [BlueTeam, RedTeam]
for side, team, obj, tstats in zip(sides, teams, objStats, teamStats):
    teamSide = side.get_attribute('class').split('-')[1].capitalize()
    topPlayer = side.find_element('xpath', './div[1]/div[4]/div[1]/a').text
    print(topPlayer)
    topChamp = side.find_element('xpath', './div[1]/div/span').get_attribute('title')
    jgPlayer = side.find_element('xpath', './div[2]/div[4]/div[1]/a').text
    print(jgPlayer)
    jgChamp = side.find_element('xpath', './div[2]/div/span').get_attribute('title')
    midPlayer = side.find_element('xpath', './div[3]/div[4]/div[1]/a').text
    midChamp = side.find_element('xpath', './div[3]/div/span').get_attribute('title')
    botPlayer = side.find_element('xpath', './div[4]/div[4]/div[1]/a').text
    botChamp = side.find_element('xpath', './div[4]/div/span').get_attribute('title')
    suppPlayer = side.find_element('xpath', './div[5]/div[4]/div[1]/a').text
    suppChamp = side.find_element('xpath', './div[5]/div/span').get_attribute('title')
    
    towerStats = obj.find_element('xpath', './div/div[2]/div[1]').text
    inhibitorStats = obj.find_element('xpath', './div/div[2]/div[2]').text
    baronStats = obj.find_element('xpath', './div/div[2]/div[3]').text
    dragonStats = obj.find_element('xpath', './div/div[2]/div[4]').text
    heraldStats = obj.find_element('xpath', './div/div[2]/div[5]').text
    
    Victory = 1 if tstats.find_element('xpath', './div/div[1]').text=='Victory' else 0
    TeamGold = tstats.find_element('xpath', './div/div[2]').text.replace('k', '')
    TeamKills = tstats.find_element('xpath', './div/div[3]').text
    
    
    sideData = [gameLength, teamSide, team, topPlayer, topChamp, jgPlayer, jgChamp, midPlayer, midChamp, botPlayer, botChamp, suppPlayer, suppChamp, TeamKills, TeamGold, towerStats, inhibitorStats, baronStats, dragonStats, heraldStats, Victory]
    data_dict = {k:v for (k,v) in zip(columns, sideData)}
    matchData.append(data_dict)
    
data_dict = {k:v for (k,v) in zip(columns, matchData)}
df=pd.DataFrame.from_records(matchData)
# Out:
# Fudge
# Blaber
# Wunder
# Razork

# %%
df
# Out:
#    Match Length (minutes)  Side    Team     Top Top Champion  Jungle  \
# 0                    32.4  Blue  Cloud9   Fudge        Fiora  Blaber
# 1                    32.4   Red  Fnatic  Wunder         Ornn  Razork
#
#   Jungle Champion       Mid Mid Champion     Bottom  ...    Support  \
# 0         Sejuani    Jensen      LeBlanc  Berserker  ...       Zven
# 1          Maokai  Humanoid         Azir      Upset  ...  Hylissang
#
#   Support Champion Total Team Kills Total Team Gold (k) Towers Inhibitors  \
# 0         Nautilus                6                52.1      3          0
# 1     Renata Glasc               15                60.5      9          1
#
#   Barons Dragons Heralds Victory
# 0      0       1       2       0
# 1      1       4       0       1
#
# [2 rows x 21 columns]

# %%
TeamGold = tstats.find_element('xpath', './div[2]')

# %%
daysTabs = driver.find_elements('xpath', '//div/div[2]/div[4]/div/div')
tabsArray = np.arange(1, len(daysTabs)+1)
i=1
for x in tabsArray:
    tabs=driver.find_element('xpath', '//div/div[2]/div[4]/div[' + str(x) +']/div')
    print(tabs.text)
    tabs.click()
    time.sleep(10)
    scoreboards_found = driver.find_elements('xpath', '/html/body/div[4]/div[3]/div[3]/main/div[3]/div[1]/div/div[2]/div/table/tbody')
    driver.implicitly_wait(20)
    showall = driver.find_element('css selector', 'div.expand-contract-button:nth-child(9) > span:nth-child(1)')
    showall.click()
    driver.implicitly_wait(20)
    #WebDriverWait(driver, 20).until(EC.element_to_be_clickable(('css selector', 'div.expand-contract-button:nth-child(9) > span:nth-child(1)'))).click()
    matchData = []
    for s in scoreboards_found:
        columns = ['Game Number', 'Match Length (minutes)', 'Side', 'Team', 'Top', 'Top Champion', 'Jungle', 'Jungle Champion', 'Mid', 'Mid Champion', 'Bottom', 'Bottom Champion', 'Support', 'Support Champion', 'Total Team Kills', 'Total Team Gold (k)', 'Towers', 'Inhibitors', 'Barons', 'Dragons', 'Heralds', 'Victory']
        BlueTeam= s.find_element('xpath', './tr[1]/th[1]/span/span[2]/a').text
        RedTeam= s.find_element('xpath', './tr[1]/th[3]/span/span[1]/a').text
        sides = s.find_elements('xpath', './tr[5]/td')
        teamStats = [s.find_element('xpath', './tr[3]/th[1]'), s.find_element('xpath', './tr[3]/th[3]')]
        gameLength = np.round((float(s.find_element('xpath', './tr[3]/th[2]').text.split(':')[0]) + np.divide(float(s.find_element('xpath', './tr[3]/th[2]').text.split(':')[1]), 60)), 2)
        objStats = s.find_elements('xpath', './tr[7]/td')
        teams = [BlueTeam, RedTeam]
        for side, team, obj, tstats in zip(sides, teams, objStats, teamStats):
            teamSide = side.get_attribute('class').split('-')[1].capitalize()
            topPlayer = side.find_element('xpath', './div[1]/div[4]/div[1]/a').text
            #print(topPlayer)
            topChamp = side.find_element('xpath', './div[1]/div/span').get_attribute('title')
            jgPlayer = side.find_element('xpath', './div[2]/div[4]/div[1]/a').text
            #print(jgPlayer)
            jgChamp = side.find_element('xpath', './div[2]/div/span').get_attribute('title')
            midPlayer = side.find_element('xpath', './div[3]/div[4]/div[1]/a').text
            midChamp = side.find_element('xpath', './div[3]/div/span').get_attribute('title')
            botPlayer = side.find_element('xpath', './div[4]/div[4]/div[1]/a').text
            botChamp = side.find_element('xpath', './div[4]/div/span').get_attribute('title')
            suppPlayer = side.find_element('xpath', './div[5]/div[4]/div[1]/a').text
            suppChamp = side.find_element('xpath', './div[5]/div/span').get_attribute('title')

            towerStats = obj.find_element('xpath', './div/div[2]/div[1]').text
            inhibitorStats = obj.find_element('xpath', './div/div[2]/div[2]').text
            baronStats = obj.find_element('xpath', './div/div[2]/div[3]').text
            dragonStats = obj.find_element('xpath', './div/div[2]/div[4]').text
            heraldStats = obj.find_element('xpath', './div/div[2]/div[5]').text

            Victory = 1 if tstats.find_element('xpath', './div/div[1]').text=='Victory' else 0
            TeamGold = tstats.find_element('xpath', './div/div[2]').text.replace('k', '')
            TeamKills = tstats.find_element('xpath', './div/div[3]').text


            sideData = [str(i), gameLength, teamSide, team, topPlayer, topChamp, jgPlayer, jgChamp, midPlayer, midChamp, botPlayer, botChamp, suppPlayer, suppChamp, TeamKills, TeamGold, towerStats, inhibitorStats, baronStats, dragonStats, heraldStats, Victory]
            data_dict = {k:v for (k,v) in zip(columns, sideData)}
            matchData.append(data_dict)

        data_dict = {k:v for (k,v) in zip(columns, matchData)}
        df=pd.DataFrame.from_records(matchData)
        i+=1
        
driver.quit()
# Out:
# Days 1-2
# Days 3-4
# Days 5-6
# Days 7-8
# Tiebreakers
# Quarterfinals
# Semifinals and Finals

# %%
df
# Out:
#    Game Number  Match Length (minutes)  Side       Team     Top Top Champion  \
# 0           68                   39.88  Blue         T1    Zeus      Camille
# 1           68                   39.88   Red  JD Gaming     369          Jax
# 2           69                   34.00  Blue         T1    Zeus         Yone
# 3           69                   34.00   Red  JD Gaming     369     Malphite
# 4           70                   30.90  Blue  JD Gaming     369     Renekton
# 5           70                   30.90   Red         T1    Zeus    Gangplank
# 6           71                   24.90  Blue  JD Gaming     369      Sejuani
# 7           71                   24.90   Red         T1    Zeus       Gragas
# 8           72                   29.67  Blue      Gen.G   Doran        Fiora
# 9           72                   29.67   Red        DRX  Kingen      Camille
# 10          73                   39.40  Blue        DRX  Kingen       Gragas
# 11          73                   39.40   Red      Gen.G   Doran         Ornn
# 12          74                   30.15  Blue      Gen.G   Doran      Sejuani
# 13          74                   30.15   Red        DRX  Kingen         Ornn
# 14          75                   37.82  Blue      Gen.G   Doran     Renekton
# 15          75                   37.82   Red        DRX  Kingen       Gragas
# 16          76                   31.18  Blue         T1    Zeus         Yone
# 17          76                   31.18   Red        DRX  Kingen       Aatrox
# 18          77                   46.20  Blue        DRX  Kingen      Camille
# 19          77                   46.20   Red         T1    Zeus       Aatrox
# 20          78                   32.20  Blue         T1    Zeus       Gragas
# 21          78                   32.20   Red        DRX  Kingen         Ornn
# 22          79                   28.75  Blue        DRX  Kingen       Aatrox
# 23          79                   28.75   Red         T1    Zeus        Fiora
# 24          80                   42.15  Blue         T1    Zeus         Gwen
# 25          80                   42.15   Red        DRX  Kingen       Aatrox
#
#     Jungle Jungle Champion    Mid Mid Champion  ...  Support Support Champion  \
# 0     Oner              Vi  Faker        Galio  ...    Keria             Nami
# 1   Kanavi           Viego  Yagao      Taliyah  ...  Missing             Lulu
# 2     Oner           Poppy  Faker         Ryze  ...    Keria             Nami
# 3   Kanavi        Bel'Veth  Yagao        Sylas  ...  Missing             Lulu
# 4   Kanavi           Viego  Yagao         Azir  ...  Missing             Lulu
# 5     Oner        Nocturne  Faker         Ryze  ...    Keria             Nami
# 6   Kanavi        Bel'Veth  Yagao        Sylas  ...  Missing            Karma
# 7     Oner           Viego  Faker         Azir  ...    Keria     Renata Glasc
# 8   Peanut           Viego  Chovy        Sylas  ...  Lehends       Tahm Kench
# 9   Pyosik         Sejuani   Zeka         Azir  ...    BeryL           Soraka
# 10  Pyosik         Kindred   Zeka         Ahri  ...    BeryL              Lux
# 11  Peanut          Graves  Chovy        Sylas  ...  Lehends            Karma
# 12  Peanut         Trundle  Chovy         Azir  ...  Lehends            Karma
# 13  Pyosik           Viego   Zeka        Akali  ...    BeryL     Renata Glasc
# 14  Peanut           Viego  Chovy         Ryze  ...  Lehends         Nautilus
# 15  Pyosik         Kindred   Zeka        Galio  ...    BeryL            Braum
# 16    Oner         Lee Sin  Faker         Azir  ...    Keria     Renata Glasc
# 17  Pyosik           Viego   Zeka        Sylas  ...    BeryL     Heimerdinger
# 18  Pyosik           Viego   Zeka        Sylas  ...    BeryL     Heimerdinger
# 19    Oner          Graves  Faker       Viktor  ...    Keria              Lux
# 20    Oner          Graves  Faker         Azir  ...    Keria            Karma
# 21  Pyosik           Viego   Zeka        Sylas  ...    BeryL     Renata Glasc
# 22  Pyosik          Maokai   Zeka         Azir  ...    BeryL     Renata Glasc
# 23    Oner         Sejuani  Faker        Akali  ...    Keria           Soraka
# 24    Oner           Viego  Faker       Viktor  ...    Keria            Karma
# 25  Pyosik         Hecarim   Zeka         Azir  ...    BeryL             Bard
#
#    Total Team Kills Total Team Gold (k) Towers Inhibitors Barons Dragons  \
# 0                14                68.9      5          0      1       1
# 1                20                73.4      8          1      0       5
# 2                17                67.2     10          3      2       2
# 3                11                  58      3          0      0       3
# 4                18                57.4      3          0      0       1
# 5                23                67.1     10          2      2       3
# 6                 7                40.5      2          0      0       0
# 7                30                53.9     10          2      1       4
# 8                12                58.5     10          2      1       2
# 9                 2                44.9      2          0      0       2
# 10                9                70.2      8          1      1       5
# 11                3                62.6      5          2      0       1
# 12                5                  48      3          0      0       1
# 13               20                59.2      8          1      1       3
# 14                8                60.2      2          0      0       2
# 15               15                69.8     10          2      2       4
# 16               15                61.5     11          5      2       4
# 17                5                50.4      0          0      0       1
# 18               17                80.5      9          1      1       3
# 19               13                79.6      4          0      0       4
# 20               12                60.1     10          2      2       3
# 21               12                53.8      3          0      0       2
# 22               14                54.8      9          2      1       3
# 23                4                46.4      3          0      0       1
# 24               10                72.1      8          2      2       2
# 25               19                74.7      8          1      0       5
#
#    Heralds Victory
# 0        1       0
# 1        1       1
# 2        1       1
# 3        1       0
# 4        2       0
# 5        0       1
# 6        2       0
# 7        0       1
# 8        2       1
# 9        0       0
# 10       1       1
# 11       1       0
# 12       2       0
# 13       0       1
# 14       1       0
# 15       1       1
# 16       1       1
# 17       1       0
# 18       1       1
# 19       1       0
# 20       0       1
# 21       2       0
# 22       1       1
# 23       1       0
# 24       1       0
# 25       1       1
#
# [26 rows x 22 columns]

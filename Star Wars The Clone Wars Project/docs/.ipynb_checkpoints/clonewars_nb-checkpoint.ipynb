# %%
import pandas as pd
import re

# %%
df = pd.read_csv('../data/clonewars_cleaned.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#                              name  \
# 0                          Ambush
# 1              Rising Malevolence
# 2           Shadow of Malevolence
# 3             Destroy Malevolence
# 4                         Rookies
# 5             Downfall of a Droid
# 6              Duel of the Droids
# 7                     Bombad Jedi
# 8               Cloak of Darkness
# 9                Lair of Grievous
# 10                 Dooku Captured
# 11             The Gungan General
# 12                     Jedi Crash
# 13             Defenders of Peace
# 14                       Trespass
# 15               The Hidden Enemy
# 16              Blue Shadow Virus
# 17    Mystery of a Thousand Moons
# 18              Storm Over Ryloth
# 19            Innocents of Ryloth
# 20              Liberty on Ryloth
# 21                 Hostage Crisis
# 22                 Holocron Heist
# 23                  Cargo of Doom
# 24          Children of the Force
# 25                     Senate Spy
# ...

# %%
t=df.loc[1]['synopsis']
t
# Out:
# 'An attack by a devastating new Separatist weapon—the powerful starship Malevolence—leaves Jedi Master Plo Koon and his clone troopers struggling to survive until Anakin and Ahsoka can find them.'

# %%
pt = re.sub(r'[^\x00-\x7fj]',r'', t)

# %%
pt
# Out:
# 'An attack by a devastating new Separatist weaponthe powerful starship Malevolenceleaves Jedi Master Plo Koon and his clone troopers struggling to survive until Anakin and Ahsoka can find them.'
